# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import seaborn
from pytrends.request import TrendReq
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, HuberRegressor, SGDRegressor, TweedieRegressor 
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, StackingRegressor, AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR, SVR
from sklearn.neural_network import MLPRegressor
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Flatten, Bidirectional, GRU, Conv1D, MaxPooling1D, ConvLSTM1D
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError, MeanAbsolutePercentageError
import keras
from sklearn.decomposition import PCA

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i,0]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]    
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i,0]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        y=pd.concat([y,TSeries.iloc[end_ix]], ignore_index = True)
    return X,y

# %%
def get_multi_pattern(normalizedData1,LagLength,n_keywords):
    x = []
    k=0
    while(k<=218):
        temp=[]
        for i in range(LagLength):
            for j in range(n_keywords):
                if(i+k)<231:
                    temp.append(normalizedData1.iloc[i+k,j])
        x.append(temp)
        k=k+1
    return pd.DataFrame(x)

# %%
def Find_Fitness(x,y,lenValid,lenTest,model):
    NOP=y.shape[0]
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model.fit(xTrain, yTrain)
    yhatNorm=model.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findSMAPE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainSMAPE=0;
    for i in range (lenTrainValidation):
        trainSMAPE=trainSMAPE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/((np.abs(forecasted_value.iloc[i,0])+np.abs(Timeseries_Data.iloc[i,0]))/2))
    
    trainSMAPE=(trainSMAPE/(lenTrainValidation))*100;

    testSMAPE=0;
    for i in range (lenTrainValidation,l,1):
        testSMAPE=testSMAPE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/((np.abs(forecasted_value.iloc[i,0])+np.abs(Timeseries_Data.iloc[i,0]))/2))
    
    testSMAPE=(testSMAPE/lenTest)*100;
    return trainSMAPE, testSMAPE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMASE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMASE=0;
    T1=Timeseries_Data.iloc[0:lenTrainValidation,0]
    T2=T1.diff()
    T2=T2.drop(0)
    T2=np.abs(T2)
    M=np.mean(T2)
    for i in range (lenTrainValidation):
        trainMASE=trainMASE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/M) 

    trainMASE=(trainMASE/(lenTrainValidation))

    testMASE=0
    T1=Timeseries_Data.iloc[lenTrainValidation:l,0]
    T2=T1.diff()
    T2=T2.drop(lenTrainValidation)
    T2=np.abs(T2)
    M=np.mean(T2)
    for i in range (lenTrainValidation,l,1):
        testMASE=testMASE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/M)
    testMASE=(testMASE/lenTest)
    return trainMASE,testMASE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Fitness_BiGRU(x,y,lenValid,lenTest):
    NOP=len(y);   
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(Bidirectional(GRU(256, activation='relu'), input_shape=(LagLength,n_features), name="feature_layer"))
    model1.add(Flatten())
    model1.add(Dense(128, activation='relu'))
    model1.add(Dense(64, activation='relu'))
    model1.add(Dense(32, activation='relu'))
    model1.add(Dense(16, activation='relu'))
    model1.add(Dense(1,activation='linear'))
    cp1=ModelCheckpoint('./model1.keras',save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError(),MeanAbsolutePercentageError()])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=50, verbose=1,callbacks=[cp1])
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    feature_extractor = keras.Model(inputs=model1.inputs, outputs=model1.get_layer(name="feature_layer").output,)
    features = feature_extractor(x.values.reshape(x.shape[0],x.shape[1],1))
    return pd.DataFrame(yhatNorm), pd.DataFrame(features)

# %%
#Read the Time Series Dataset
from pytrends.request import TrendReq
Timeseries_Data=pd.read_csv('crude_oil_prices.csv',header=None)
#Get the google trends dataset

# %%
Timeseries_Data.head()
# Out:
#        0       1
# 0  31.37  Jan-04
# 1  31.33  Feb-04
# 2  33.67  Mar-04
# 3  33.71  Apr-04
# 4  37.56  May-04

# %%
Timeseries_Data.tail()
# Out:
#          0       1
# 226  87.38  Nov-22
# 227  78.07  Dec-22
# 228  80.41  Jan-23
# 229  80.25  Feb-23
# 230  76.47  Mar-23

# %%
LagLength=12
h=1
n_features = 1
n_keywords = 4
NumberOfRepeatitions=20

# %%
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.6))
lenValidation=int(round(lt*0.2))
lenTest=int(lt-lenTrain-lenValidation)
print((Timeseries_Data.shape))
# Out:
# (231, 2)

# %%
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Timeseries_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X1, y1 = get_Patterns(normalizedData, LagLength, h)
#apply the data to train lstm and extract features

print(X1.shape)
print(y1.shape)
# Out:
# (219, 12)
# (219, 1)

# %%
lstm_predict,features=Find_Fitness_BiGRU(X1,y1,lenValidation,lenTest)
#remove empty columns/features
truncated_features = features.loc[:,(features!=0).any(axis=0)]
#reduce dimensionality using pca
pca1 = PCA(n_components=4)
final_features_hist = pca1.fit_transform(truncated_features.values)
final_features_hist = pd.DataFrame(final_features_hist)
# Out:
# C:\Users\lohit\anaconda3\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 761ms/step - loss: 0.1512 - mean_absolute_percentage_error: 71.5994 - root_mean_squared_error: 0.3833 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 6736031.5000 - val_root_mean_squared_error: 0.1392
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0382 - mean_absolute_percentage_error: 37.9389 - root_mean_squared_error: 0.1953 - val_loss: 0.0744 - val_mean_absolute_percentage_error: 9808047.0000 - val_root_mean_squared_error: 0.2728
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0364 - mean_absolute_percentage_error: 49.4240 - root_mean_squared_error: 0.1906 - val_loss: 0.0155 - val_mean_absolute_percentage_error: 6277154.0000 - val_root_mean_squared_error: 0.1244
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0314 - mean_absolute_percentage_error: 35.6176 - root_mean_squared_error: 0.1768 - val_loss: 0.0380 - val_mean_absolute_percentage_error: 7769956.0000 - val_root_mean_squared_error: 0.1951
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0192 - mean_absolute_percentage_error: 37.0035 - root_mean_squared_error: 0.1382 - val_loss: 0.0087 - val_mean_absolute_percentage_error: 5140820.0000 - val_root_mean_squared_error: 0.0930
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0142 - mean_absolute_percentage_error: 22.5981 - root_mean_squared_error: 0.1190 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 4823294.0000 - val_root_mean_squared_error: 0.0907
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0085 - mean_absolute_percentage_error: 18.6017 - root_mean_squared_error: 0.0919 - val_loss: 0.0046 - val_mean_absolute_percentage_error: 3985545.7500 - val_root_mean_squared_error: 0.0677
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0055 - mean_absolute_percentage_error: 15.3707 - root_mean_squared_error: 0.0735 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 3597031.0000 - val_root_mean_squared_error: 0.0719
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0087 - mean_absolute_percentage_error: 18.9288 - root_mean_squared_error: 0.0934 - val_loss: 0.0092 - val_mean_absolute_percentage_error: 4527399.5000 - val_root_mean_squared_error: 0.0960
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0080 - mean_absolute_percentage_error: 18.9671 - root_mean_squared_error: 0.0894 - val_loss: 0.0037 - val_mean_absolute_percentage_error: 3851363.5000 - val_root_mean_squared_error: 0.0612
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0069 - mean_absolute_percentage_error: 16.2687 - root_mean_squared_error: 0.0829 - val_loss: 0.0039 - val_mean_absolute_percentage_error: 3922945.5000 - val_root_mean_squared_error: 0.0626
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0036 - mean_absolute_percentage_error: 11.7787 - root_mean_squared_error: 0.0593 - val_loss: 0.0039 - val_mean_absolute_percentage_error: 3819158.5000 - val_root_mean_squared_error: 0.0622
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0045 - mean_absolute_percentage_error: 13.8144 - root_mean_squared_error: 0.0666 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 3640346.0000 - val_root_mean_squared_error: 0.0571
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0034 - mean_absolute_percentage_error: 12.5897 - root_mean_squared_error: 0.0583 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 3459954.7500 - val_root_mean_squared_error: 0.0546
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0030 - mean_absolute_percentage_error: 10.9674 - root_mean_squared_error: 0.0552 - val_loss: 0.0038 - val_mean_absolute_percentage_error: 3722760.0000 - val_root_mean_squared_error: 0.0617
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0040 - mean_absolute_percentage_error: 12.6087 - root_mean_squared_error: 0.0630 - val_loss: 0.0044 - val_mean_absolute_percentage_error: 3794993.7500 - val_root_mean_squared_error: 0.0666
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0028 - mean_absolute_percentage_error: 11.0512 - root_mean_squared_error: 0.0531 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 3435088.2500 - val_root_mean_squared_error: 0.0533
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0027 - mean_absolute_percentage_error: 10.3461 - root_mean_squared_error: 0.0518 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 3453162.5000 - val_root_mean_squared_error: 0.0554
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0030 - mean_absolute_percentage_error: 11.1171 - root_mean_squared_error: 0.0547 - val_loss: 0.0049 - val_mean_absolute_percentage_error: 3638987.2500 - val_root_mean_squared_error: 0.0697
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0032 - mean_absolute_percentage_error: 12.4011 - root_mean_squared_error: 0.0561 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 3233359.7500 - val_root_mean_squared_error: 0.0513
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0032 - mean_absolute_percentage_error: 10.9078 - root_mean_squared_error: 0.0564 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 3193335.7500 - val_root_mean_squared_error: 0.0515
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0034 - mean_absolute_percentage_error: 11.7327 - root_mean_squared_error: 0.0583 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 3673247.0000 - val_root_mean_squared_error: 0.0758
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0046 - mean_absolute_percentage_error: 13.6875 - root_mean_squared_error: 0.0676 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 3200010.5000 - val_root_mean_squared_error: 0.0522
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0037 - mean_absolute_percentage_error: 12.1253 - root_mean_squared_error: 0.0605 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 3319977.0000 - val_root_mean_squared_error: 0.0525
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0033 - mean_absolute_percentage_error: 11.1534 - root_mean_squared_error: 0.0577 - val_loss: 0.0044 - val_mean_absolute_percentage_error: 3732754.5000 - val_root_mean_squared_error: 0.0663
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0035 - mean_absolute_percentage_error: 11.7386 - root_mean_squared_error: 0.0592 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 3466657.7500 - val_root_mean_squared_error: 0.0545
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0040 - mean_absolute_percentage_error: 12.1754 - root_mean_squared_error: 0.0633 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 3196980.7500 - val_root_mean_squared_error: 0.0512
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0035 - mean_absolute_percentage_error: 11.6805 - root_mean_squared_error: 0.0589 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 3482521.0000 - val_root_mean_squared_error: 0.0587
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0032 - mean_absolute_percentage_error: 10.7611 - root_mean_squared_error: 0.0561 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 3478273.7500 - val_root_mean_squared_error: 0.0573
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0028 - mean_absolute_percentage_error: 10.0852 - root_mean_squared_error: 0.0524 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 3319096.2500 - val_root_mean_squared_error: 0.0520
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0031 - mean_absolute_percentage_error: 11.0376 - root_mean_squared_error: 0.0560 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 3380018.7500 - val_root_mean_squared_error: 0.0539
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0027 - mean_absolute_percentage_error: 10.0572 - root_mean_squared_error: 0.0517 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 3364648.7500 - val_root_mean_squared_error: 0.0545
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0030 - mean_absolute_percentage_error: 10.4458 - root_mean_squared_error: 0.0549 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 3423188.2500 - val_root_mean_squared_error: 0.0547
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0026 - mean_absolute_percentage_error: 9.7510 - root_mean_squared_error: 0.0504 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 3516210.7500 - val_root_mean_squared_error: 0.0587
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0026 - mean_absolute_percentage_error: 10.7475 - root_mean_squared_error: 0.0511 - val_loss: 0.0036 - val_mean_absolute_percentage_error: 3452518.2500 - val_root_mean_squared_error: 0.0604
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0032 - mean_absolute_percentage_error: 11.5065 - root_mean_squared_error: 0.0568 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 3272520.7500 - val_root_mean_squared_error: 0.0527
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0020 - mean_absolute_percentage_error: 9.3757 - root_mean_squared_error: 0.0445 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 3151290.0000 - val_root_mean_squared_error: 0.0509
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0033 - mean_absolute_percentage_error: 11.0091 - root_mean_squared_error: 0.0572 - val_loss: 0.0061 - val_mean_absolute_percentage_error: 3749103.2500 - val_root_mean_squared_error: 0.0782
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0044 - mean_absolute_percentage_error: 13.3784 - root_mean_squared_error: 0.0658 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 3386088.7500 - val_root_mean_squared_error: 0.0553
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0028 - mean_absolute_percentage_error: 10.4596 - root_mean_squared_error: 0.0529 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 3184410.7500 - val_root_mean_squared_error: 0.0520
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0031 - mean_absolute_percentage_error: 10.3304 - root_mean_squared_error: 0.0554 - val_loss: 0.0046 - val_mean_absolute_percentage_error: 3625580.7500 - val_root_mean_squared_error: 0.0676
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0045 - mean_absolute_percentage_error: 12.5491 - root_mean_squared_error: 0.0665 - val_loss: 0.0038 - val_mean_absolute_percentage_error: 3605323.5000 - val_root_mean_squared_error: 0.0618
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0026 - mean_absolute_percentage_error: 11.3446 - root_mean_squared_error: 0.0507 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 3180834.0000 - val_root_mean_squared_error: 0.0519
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0028 - mean_absolute_percentage_error: 9.8658 - root_mean_squared_error: 0.0529 - val_loss: 0.0047 - val_mean_absolute_percentage_error: 3585688.7500 - val_root_mean_squared_error: 0.0688
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0045 - mean_absolute_percentage_error: 13.1143 - root_mean_squared_error: 0.0666 - val_loss: 0.0042 - val_mean_absolute_percentage_error: 3545890.7500 - val_root_mean_squared_error: 0.0648
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0040 - mean_absolute_percentage_error: 12.7403 - root_mean_squared_error: 0.0625 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 3038812.5000 - val_root_mean_squared_error: 0.0535
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0048 - mean_absolute_percentage_error: 12.7370 - root_mean_squared_error: 0.0693 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 3215936.0000 - val_root_mean_squared_error: 0.0528
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0026 - mean_absolute_percentage_error: 10.7220 - root_mean_squared_error: 0.0511 - val_loss: 0.0032 - val_mean_absolute_percentage_error: 3477086.0000 - val_root_mean_squared_error: 0.0565
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0026 - mean_absolute_percentage_error: 11.7274 - root_mean_squared_error: 0.0512 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 3589779.2500 - val_root_mean_squared_error: 0.0594
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0021 - mean_absolute_percentage_error: 9.8764 - root_mean_squared_error: 0.0456 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 3456583.2500 - val_root_mean_squared_error: 0.0575
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 264ms/step

# %%
MeanAccuracyT=pd.DataFrame()
StdAccuracyT=pd.DataFrame()

# %%
for j in range(0,20,1):
    print('Model:::::::::::::::::::::::::::::::',j)
    if j==0:
        model=LinearRegression()
        name='1.LinearRegression'
    elif j==1:
        model=Lasso()
        name='2.Lasso'
    elif j==2:
        model=Ridge()
        name='3.Ridge'
    elif j==3:
        model=ElasticNet()
        name='4.ElasticNet'
    elif j==4:
        model=HuberRegressor(max_iter=1000)
        name='5.HuberRegressor'
    elif j==5:
        model=SGDRegressor()
        name='6.SGDRegressor'
    elif j==6:
        model=TweedieRegressor()
        name='7.TweedieRegressor'
    elif j==7:
        model=AdaBoostRegressor()
        name='8.AdaBoostRegressor'
    elif j==8:
        model=RandomForestRegressor()
        name='9.RandomForestRegressor'
    elif j==9:
        model=GradientBoostingRegressor()
        name='10.GradientBoostingRegressor'
    elif j==10:
        model=LinearSVR()
        name='11.LinearSVR'
    elif j==11:
        model=MLPRegressor()
        name='12.MLP'
    elif j==12:
        model=SVR()
        name='13.SVR'
    elif j==13:
        model=ExtraTreesRegressor()
        name='14.ExtraTreesRegressor'
    elif j==14:
        model=BaggingRegressor()
        name='15.BaggingRegressor'
    elif j==15:
        model=DecisionTreeRegressor()
        name='16.DecisionTreeRegressor'
    elif j==16:
        model=KNeighborsRegressor()
        name='17.KNeighborsRegressor'
    elif j==17:
        model=model_xgb = xgb.XGBRegressor(verbosity=0)
        name='18.XGB'
    elif j==18:
        model=StackingRegressor(estimators=[('lr',LinearRegression()),('xgb',xgb.XGBRegressor(verbosity=0))],final_estimator=LinearRegression())
        name='19.Stacking'

    else:
        print('Completed.....................')
        continue
    file1='./'+str(name)+"_Accuracy.xlsx"
    file2='./'+str(name)+"_Forecasts.xlsx"
    Forecasts=pd.DataFrame()
    Accuracy=pd.DataFrame()
    for i in range(NumberOfRepeatitions):
        print('No. of repeatitions completed:',i)
        ynorm1=Find_Fitness(final_features_hist,y1,lenValidation,lenTest,model)
        ynorm=pd.DataFrame(normalizedData.iloc[0:(LagLength+h-1),0])
        ynorm=pd.concat([ynorm,ynorm1],ignore_index = True)
        yhat=minmaxDeNorm(Timeseries_Data, ynorm, lenTrain+lenValidation)
        Accuracy.loc[i,0],Accuracy.loc[i,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Accuracy.loc[i,2],Accuracy.loc[i,3]=findSMAPE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Accuracy.loc[i,4],Accuracy.loc[i,5]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Accuracy.loc[i,6],Accuracy.loc[i,7]=findMASE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Forecasts=pd.concat([Forecasts,yhat.T],ignore_index = True)
    Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
    Forecasts.T.to_excel(file2,sheet_name='Forecasts',index=False)
    MeanAccuracy=pd.DataFrame(np.mean(Accuracy,axis=0))    
    MeanAccuracyT=pd.concat([MeanAccuracyT,MeanAccuracy.T], ignore_index = True)
    StdAccuracy=pd.DataFrame(np.std(Accuracy,axis=0))    
    StdAccuracyT=pd.concat([StdAccuracyT,StdAccuracy.T], ignore_index = True)
    del Accuracy
    del Forecasts
    del MeanAccuracy
    del StdAccuracy
MeanAccuracyT.to_excel('All_Model_Mean_Accuracy.xlsx',sheet_name='All_Model_Accuracy',index=False)
del MeanAccuracyT
StdAccuracyT.to_excel('All_Model_Stdev_Accuracy.xlsx',sheet_name='All_Model_Stdev_Accuracy',index=False)
del StdAccuracyT
# Out:
# Model::::::::::::::::::::::::::::::: 0
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 1
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 2
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 3
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 4
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 5
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 6
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 7
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 8
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 9
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 10
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 11
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 12
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 13
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 14
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 15
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 16
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 17
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 18
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 19
# Completed.....................
