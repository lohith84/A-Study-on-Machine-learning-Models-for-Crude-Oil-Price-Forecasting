# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import seaborn
from pytrends.request import TrendReq
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, HuberRegressor, SGDRegressor, TweedieRegressor 
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, StackingRegressor, AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR, SVR
from sklearn.neural_network import MLPRegressor
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Flatten, Bidirectional, GRU, Conv1D, MaxPooling1D, ConvLSTM1D
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError, MeanAbsolutePercentageError
import keras
from sklearn.decomposition import PCA

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i,0]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]    
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i,0]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        y=pd.concat([y,TSeries.iloc[end_ix]], ignore_index = True)
    return X,y

# %%
def get_multi_pattern(normalizedData1,LagLength,n_keywords):
    x = []
    k=0
    while(k<=218):
        temp=[]
        for i in range(LagLength):
            for j in range(n_keywords):
                if(i+k)<231:
                    temp.append(normalizedData1.iloc[i+k,j])
        x.append(temp)
        k=k+1
    return pd.DataFrame(x)

# %%
def Find_Fitness(x,y,lenValid,lenTest,model):
    NOP=y.shape[0]
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model.fit(xTrain, yTrain)
    yhatNorm=model.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findSMAPE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainSMAPE=0;
    for i in range (lenTrainValidation):
        trainSMAPE=trainSMAPE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/((np.abs(forecasted_value.iloc[i,0])+np.abs(Timeseries_Data.iloc[i,0]))/2))
    
    trainSMAPE=(trainSMAPE/(lenTrainValidation))*100;

    testSMAPE=0;
    for i in range (lenTrainValidation,l,1):
        testSMAPE=testSMAPE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/((np.abs(forecasted_value.iloc[i,0])+np.abs(Timeseries_Data.iloc[i,0]))/2))
    
    testSMAPE=(testSMAPE/lenTest)*100;
    return trainSMAPE, testSMAPE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMASE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMASE=0;
    T1=Timeseries_Data.iloc[0:lenTrainValidation,0]
    T2=T1.diff()
    T2=T2.drop(0)
    T2=np.abs(T2)
    M=np.mean(T2)
    for i in range (lenTrainValidation):
        trainMASE=trainMASE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/M) 

    trainMASE=(trainMASE/(lenTrainValidation))

    testMASE=0
    T1=Timeseries_Data.iloc[lenTrainValidation:l,0]
    T2=T1.diff()
    T2=T2.drop(lenTrainValidation)
    T2=np.abs(T2)
    M=np.mean(T2)
    for i in range (lenTrainValidation,l,1):
        testMASE=testMASE+(np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])/M)
    testMASE=(testMASE/lenTest)
    return trainMASE,testMASE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Fitness_GRU(x,y,lenValid,lenTest):
    NOP=len(y);   
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(GRU(256, activation='relu', return_sequences=True, input_shape=(LagLength,n_features), name="feature_layer_1"))
    model1.add(GRU(128, activation='relu', return_sequences=True, input_shape=(LagLength,n_features), name="feature_layer_2"))
    model1.add(GRU(64, activation='relu', return_sequences=False, input_shape=(LagLength,n_features), name="feature_layer_3"))
    model1.add(Flatten())
    #model1.add(Dense(128, activation='relu'))
    #model1.add(Dense(64, activation='relu'))
    model1.add(Dense(32, activation='sigmoid'))
    model1.add(Dense(16, activation='sigmoid'))
    model1.add(Dense(1,activation='linear'))
    cp1=ModelCheckpoint('./model1.keras',save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError(),MeanAbsolutePercentageError()])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=50, verbose=1,callbacks=[cp1])
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    feature_extractor = keras.Model(inputs=model1.inputs, outputs=model1.get_layer(name="feature_layer_3").output,)
    features = feature_extractor(x.values.reshape(x.shape[0],x.shape[1],1))
    return pd.DataFrame(yhatNorm), pd.DataFrame(features)

# %%
#Read the Time Series Dataset
from pytrends.request import TrendReq
Timeseries_Data=pd.read_csv('crude_oil_prices.csv',header=None)
#Get the google trends dataset

# %%
Timeseries_Data.head()
# Out:
#        0       1
# 0  31.37  Jan-04
# 1  31.33  Feb-04
# 2  33.67  Mar-04
# 3  33.71  Apr-04
# 4  37.56  May-04

# %%
Timeseries_Data.tail()
# Out:
#          0       1
# 226  87.38  Nov-22
# 227  78.07  Dec-22
# 228  80.41  Jan-23
# 229  80.25  Feb-23
# 230  76.47  Mar-23

# %%
LagLength=12
h=1
n_features = 1
n_keywords = 4
NumberOfRepeatitions=20

# %%
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.6))
lenValidation=int(round(lt*0.2))
lenTest=int(lt-lenTrain-lenValidation)
print((Timeseries_Data.shape))
# Out:
# (231, 2)

# %%
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Timeseries_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X1, y1 = get_Patterns(normalizedData, LagLength, h)
#apply the data to train lstm and extract features

print(X1.shape)
print(y1.shape)
# Out:
# (219, 12)
# (219, 1)

# %%
lstm_predict,features=Find_Fitness_GRU(X1,y1,lenValidation,lenTest)
#remove empty columns/features
truncated_features = features.loc[:,(features!=0).any(axis=0)]
#reduce dimensionality using pca
pca1 = PCA(n_components=4)
final_features_hist = pca1.fit_transform(truncated_features.values)
final_features_hist = pd.DataFrame(final_features_hist)
# Out:
# C:\Users\lohit\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - loss: 0.6149 - mean_absolute_percentage_error: 173.6438 - root_mean_squared_error: 0.7758 - val_loss: 0.3004 - val_mean_absolute_percentage_error: 16860538.0000 - val_root_mean_squared_error: 0.5481
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 0.1046 - mean_absolute_percentage_error: 91.5462 - root_mean_squared_error: 0.3228 - val_loss: 0.1939 - val_mean_absolute_percentage_error: 14444772.0000 - val_root_mean_squared_error: 0.4404
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - loss: 0.0705 - mean_absolute_percentage_error: 77.5504 - root_mean_squared_error: 0.2653 - val_loss: 0.1111 - val_mean_absolute_percentage_error: 12006154.0000 - val_root_mean_squared_error: 0.3333
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - loss: 0.0541 - mean_absolute_percentage_error: 65.3982 - root_mean_squared_error: 0.2326 - val_loss: 0.0485 - val_mean_absolute_percentage_error: 9293781.0000 - val_root_mean_squared_error: 0.2202
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.0560 - mean_absolute_percentage_error: 47.1886 - root_mean_squared_error: 0.2367 - val_loss: 0.0532 - val_mean_absolute_percentage_error: 9555610.0000 - val_root_mean_squared_error: 0.2306
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - loss: 0.0494 - mean_absolute_percentage_error: 48.0666 - root_mean_squared_error: 0.2223 - val_loss: 0.0908 - val_mean_absolute_percentage_error: 11260454.0000 - val_root_mean_squared_error: 0.3013
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - loss: 0.0476 - mean_absolute_percentage_error: 54.2236 - root_mean_squared_error: 0.2179 - val_loss: 0.1216 - val_mean_absolute_percentage_error: 12362891.0000 - val_root_mean_squared_error: 0.3487
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0511 - mean_absolute_percentage_error: 64.8495 - root_mean_squared_error: 0.2260 - val_loss: 0.0884 - val_mean_absolute_percentage_error: 11168582.0000 - val_root_mean_squared_error: 0.2974
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.0495 - mean_absolute_percentage_error: 57.9313 - root_mean_squared_error: 0.2224 - val_loss: 0.0714 - val_mean_absolute_percentage_error: 10452878.0000 - val_root_mean_squared_error: 0.2673
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 0.0495 - mean_absolute_percentage_error: 52.7670 - root_mean_squared_error: 0.2224 - val_loss: 0.0771 - val_mean_absolute_percentage_error: 10703843.0000 - val_root_mean_squared_error: 0.2777
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0519 - mean_absolute_percentage_error: 58.0241 - root_mean_squared_error: 0.2278 - val_loss: 0.0924 - val_mean_absolute_percentage_error: 11324147.0000 - val_root_mean_squared_error: 0.3040
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0450 - mean_absolute_percentage_error: 53.3510 - root_mean_squared_error: 0.2119 - val_loss: 0.0937 - val_mean_absolute_percentage_error: 11372981.0000 - val_root_mean_squared_error: 0.3061
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0506 - mean_absolute_percentage_error: 57.0326 - root_mean_squared_error: 0.2249 - val_loss: 0.0834 - val_mean_absolute_percentage_error: 10966573.0000 - val_root_mean_squared_error: 0.2888
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.0491 - mean_absolute_percentage_error: 57.2443 - root_mean_squared_error: 0.2216 - val_loss: 0.0753 - val_mean_absolute_percentage_error: 10626301.0000 - val_root_mean_squared_error: 0.2745
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0483 - mean_absolute_percentage_error: 47.6547 - root_mean_squared_error: 0.2196 - val_loss: 0.0923 - val_mean_absolute_percentage_error: 11320402.0000 - val_root_mean_squared_error: 0.3038
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 0.0477 - mean_absolute_percentage_error: 55.6934 - root_mean_squared_error: 0.2184 - val_loss: 0.0845 - val_mean_absolute_percentage_error: 11009491.0000 - val_root_mean_squared_error: 0.2906
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 0.0480 - mean_absolute_percentage_error: 56.6944 - root_mean_squared_error: 0.2190 - val_loss: 0.0771 - val_mean_absolute_percentage_error: 10703452.0000 - val_root_mean_squared_error: 0.2777
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 0.0531 - mean_absolute_percentage_error: 60.9946 - root_mean_squared_error: 0.2303 - val_loss: 0.0871 - val_mean_absolute_percentage_error: 11113947.0000 - val_root_mean_squared_error: 0.2950
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0485 - mean_absolute_percentage_error: 57.8834 - root_mean_squared_error: 0.2203 - val_loss: 0.0924 - val_mean_absolute_percentage_error: 11323378.0000 - val_root_mean_squared_error: 0.3040
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0438 - mean_absolute_percentage_error: 52.8204 - root_mean_squared_error: 0.2087 - val_loss: 0.0879 - val_mean_absolute_percentage_error: 11146385.0000 - val_root_mean_squared_error: 0.2964
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0500 - mean_absolute_percentage_error: 58.0528 - root_mean_squared_error: 0.2235 - val_loss: 0.0725 - val_mean_absolute_percentage_error: 10500205.0000 - val_root_mean_squared_error: 0.2692
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.0522 - mean_absolute_percentage_error: 55.3617 - root_mean_squared_error: 0.2282 - val_loss: 0.0921 - val_mean_absolute_percentage_error: 11311169.0000 - val_root_mean_squared_error: 0.3034
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.0426 - mean_absolute_percentage_error: 50.4160 - root_mean_squared_error: 0.2060 - val_loss: 0.0917 - val_mean_absolute_percentage_error: 11297527.0000 - val_root_mean_squared_error: 0.3029
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 0.0506 - mean_absolute_percentage_error: 61.9538 - root_mean_squared_error: 0.2248 - val_loss: 0.0748 - val_mean_absolute_percentage_error: 10602071.0000 - val_root_mean_squared_error: 0.2735
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0465 - mean_absolute_percentage_error: 53.1759 - root_mean_squared_error: 0.2156 - val_loss: 0.0864 - val_mean_absolute_percentage_error: 11088118.0000 - val_root_mean_squared_error: 0.2939
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0484 - mean_absolute_percentage_error: 60.1236 - root_mean_squared_error: 0.2199 - val_loss: 0.0914 - val_mean_absolute_percentage_error: 11286705.0000 - val_root_mean_squared_error: 0.3024
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.0495 - mean_absolute_percentage_error: 58.5296 - root_mean_squared_error: 0.2224 - val_loss: 0.0857 - val_mean_absolute_percentage_error: 11058222.0000 - val_root_mean_squared_error: 0.2927
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.0504 - mean_absolute_percentage_error: 59.4684 - root_mean_squared_error: 0.2243 - val_loss: 0.0810 - val_mean_absolute_percentage_error: 10866279.0000 - val_root_mean_squared_error: 0.2846
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0513 - mean_absolute_percentage_error: 60.4354 - root_mean_squared_error: 0.2264 - val_loss: 0.0839 - val_mean_absolute_percentage_error: 10985104.0000 - val_root_mean_squared_error: 0.2896
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0453 - mean_absolute_percentage_error: 54.6430 - root_mean_squared_error: 0.2126 - val_loss: 0.0932 - val_mean_absolute_percentage_error: 11355008.0000 - val_root_mean_squared_error: 0.3053
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.0504 - mean_absolute_percentage_error: 63.3221 - root_mean_squared_error: 0.2244 - val_loss: 0.0847 - val_mean_absolute_percentage_error: 11021106.0000 - val_root_mean_squared_error: 0.2911
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0483 - mean_absolute_percentage_error: 51.9905 - root_mean_squared_error: 0.2196 - val_loss: 0.0867 - val_mean_absolute_percentage_error: 11097965.0000 - val_root_mean_squared_error: 0.2944
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0472 - mean_absolute_percentage_error: 54.5661 - root_mean_squared_error: 0.2172 - val_loss: 0.0790 - val_mean_absolute_percentage_error: 10784649.0000 - val_root_mean_squared_error: 0.2811
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0510 - mean_absolute_percentage_error: 55.8872 - root_mean_squared_error: 0.2258 - val_loss: 0.0844 - val_mean_absolute_percentage_error: 11006171.0000 - val_root_mean_squared_error: 0.2905
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0485 - mean_absolute_percentage_error: 54.4793 - root_mean_squared_error: 0.2201 - val_loss: 0.0836 - val_mean_absolute_percentage_error: 10973637.0000 - val_root_mean_squared_error: 0.2891
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0504 - mean_absolute_percentage_error: 57.0845 - root_mean_squared_error: 0.2245 - val_loss: 0.0849 - val_mean_absolute_percentage_error: 11028963.0000 - val_root_mean_squared_error: 0.2914
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0529 - mean_absolute_percentage_error: 58.2393 - root_mean_squared_error: 0.2299 - val_loss: 0.0854 - val_mean_absolute_percentage_error: 11048783.0000 - val_root_mean_squared_error: 0.2923
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0429 - mean_absolute_percentage_error: 49.2151 - root_mean_squared_error: 0.2068 - val_loss: 0.0802 - val_mean_absolute_percentage_error: 10833677.0000 - val_root_mean_squared_error: 0.2832
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0478 - mean_absolute_percentage_error: 54.9391 - root_mean_squared_error: 0.2185 - val_loss: 0.0823 - val_mean_absolute_percentage_error: 10922756.0000 - val_root_mean_squared_error: 0.2870
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - loss: 0.0444 - mean_absolute_percentage_error: 53.2839 - root_mean_squared_error: 0.2106 - val_loss: 0.0900 - val_mean_absolute_percentage_error: 11232412.0000 - val_root_mean_squared_error: 0.3001
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - loss: 0.0490 - mean_absolute_percentage_error: 57.5611 - root_mean_squared_error: 0.2215 - val_loss: 0.0888 - val_mean_absolute_percentage_error: 11182271.0000 - val_root_mean_squared_error: 0.2979
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.0487 - mean_absolute_percentage_error: 56.6983 - root_mean_squared_error: 0.2207 - val_loss: 0.0729 - val_mean_absolute_percentage_error: 10520644.0000 - val_root_mean_squared_error: 0.2701
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0445 - mean_absolute_percentage_error: 51.4763 - root_mean_squared_error: 0.2105 - val_loss: 0.0937 - val_mean_absolute_percentage_error: 11374343.0000 - val_root_mean_squared_error: 0.3061
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0459 - mean_absolute_percentage_error: 55.9226 - root_mean_squared_error: 0.2141 - val_loss: 0.0929 - val_mean_absolute_percentage_error: 11343800.0000 - val_root_mean_squared_error: 0.3048
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0460 - mean_absolute_percentage_error: 55.3768 - root_mean_squared_error: 0.2144 - val_loss: 0.0740 - val_mean_absolute_percentage_error: 10565433.0000 - val_root_mean_squared_error: 0.2719
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 0.0512 - mean_absolute_percentage_error: 58.7878 - root_mean_squared_error: 0.2263 - val_loss: 0.0818 - val_mean_absolute_percentage_error: 10901327.0000 - val_root_mean_squared_error: 0.2860
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0493 - mean_absolute_percentage_error: 59.4040 - root_mean_squared_error: 0.2220 - val_loss: 0.1002 - val_mean_absolute_percentage_error: 11615810.0000 - val_root_mean_squared_error: 0.3165
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0487 - mean_absolute_percentage_error: 57.7695 - root_mean_squared_error: 0.2205 - val_loss: 0.0855 - val_mean_absolute_percentage_error: 11050936.0000 - val_root_mean_squared_error: 0.2924
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0495 - mean_absolute_percentage_error: 56.7308 - root_mean_squared_error: 0.2223 - val_loss: 0.0752 - val_mean_absolute_percentage_error: 10619182.0000 - val_root_mean_squared_error: 0.2742
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0488 - mean_absolute_percentage_error: 53.6108 - root_mean_squared_error: 0.2208 - val_loss: 0.0851 - val_mean_absolute_percentage_error: 11037066.0000 - val_root_mean_squared_error: 0.2918
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 505ms/step

# %%
MeanAccuracyT=pd.DataFrame()
StdAccuracyT=pd.DataFrame()

# %%
for j in range(0,20,1):
    print('Model:::::::::::::::::::::::::::::::',j)
    if j==0:
        model=LinearRegression()
        name='1.LinearRegression'
    elif j==1:
        model=Lasso()
        name='2.Lasso'
    elif j==2:
        model=Ridge()
        name='3.Ridge'
    elif j==3:
        model=ElasticNet()
        name='4.ElasticNet'
    elif j==4:
        model=HuberRegressor(max_iter=1000)
        name='5.HuberRegressor'
    elif j==5:
        model=SGDRegressor()
        name='6.SGDRegressor'
    elif j==6:
        model=TweedieRegressor()
        name='7.TweedieRegressor'
    elif j==7:
        model=AdaBoostRegressor()
        name='8.AdaBoostRegressor'
    elif j==8:
        model=RandomForestRegressor()
        name='9.RandomForestRegressor'
    elif j==9:
        model=GradientBoostingRegressor()
        name='10.GradientBoostingRegressor'
    elif j==10:
        model=LinearSVR()
        name='11.LinearSVR'
    elif j==11:
        model=MLPRegressor()
        name='12.MLP'
    elif j==12:
        model=SVR()
        name='13.SVR'
    elif j==13:
        model=ExtraTreesRegressor()
        name='14.ExtraTreesRegressor'
    elif j==14:
        model=BaggingRegressor()
        name='15.BaggingRegressor'
    elif j==15:
        model=DecisionTreeRegressor()
        name='16.DecisionTreeRegressor'
    elif j==16:
        model=KNeighborsRegressor()
        name='17.KNeighborsRegressor'
    elif j==17:
        model=model_xgb = xgb.XGBRegressor(verbosity=0)
        name='18.XGB'
    elif j==18:
        model=StackingRegressor(estimators=[('lr',LinearRegression()),('xgb',xgb.XGBRegressor(verbosity=0))],final_estimator=LinearRegression())
        name='19.Stacking'

    else:
        print('Completed.....................')
        continue
    file1='./'+str(name)+"_Accuracy.xlsx"
    file2='./'+str(name)+"_Forecasts.xlsx"
    Forecasts=pd.DataFrame()
    Accuracy=pd.DataFrame()
    for i in range(NumberOfRepeatitions):
        print('No. of repeatitions completed:',i)
        ynorm1=Find_Fitness(final_features_hist,y1,lenValidation,lenTest,model)
        ynorm=pd.DataFrame(normalizedData.iloc[0:(LagLength+h-1),0])
        ynorm=pd.concat([ynorm,ynorm1],ignore_index = True)
        yhat=minmaxDeNorm(Timeseries_Data, ynorm, lenTrain+lenValidation)
        Accuracy.loc[i,0],Accuracy.loc[i,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Accuracy.loc[i,2],Accuracy.loc[i,3]=findSMAPE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Accuracy.loc[i,4],Accuracy.loc[i,5]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Accuracy.loc[i,6],Accuracy.loc[i,7]=findMASE( Timeseries_Data,yhat,lenTrain+lenValidation)
        Forecasts=pd.concat([Forecasts,yhat.T],ignore_index = True)
    Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
    Forecasts.T.to_excel(file2,sheet_name='Forecasts',index=False)
    MeanAccuracy=pd.DataFrame(np.mean(Accuracy,axis=0))    
    MeanAccuracyT=pd.concat([MeanAccuracyT,MeanAccuracy.T], ignore_index = True)
    StdAccuracy=pd.DataFrame(np.std(Accuracy,axis=0))    
    StdAccuracyT=pd.concat([StdAccuracyT,StdAccuracy.T], ignore_index = True)
    del Accuracy
    del Forecasts
    del MeanAccuracy
    del StdAccuracy
MeanAccuracyT.to_excel('All_Model_Mean_Accuracy.xlsx',sheet_name='All_Model_Accuracy',index=False)
del MeanAccuracyT
StdAccuracyT.to_excel('All_Model_Stdev_Accuracy.xlsx',sheet_name='All_Model_Stdev_Accuracy',index=False)
del StdAccuracyT
# Out:
# Model::::::::::::::::::::::::::::::: 0
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 1
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 2
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 3
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 4
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 5
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 6
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 7
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 8
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 9
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 10
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 2
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 8
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 17
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 18
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 11
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# C:\Users\lohit\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Model::::::::::::::::::::::::::::::: 12
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 13
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 14
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 15
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 16
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 17
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 18
# No. of repeatitions completed: 0
# No. of repeatitions completed: 1
# No. of repeatitions completed: 2
# No. of repeatitions completed: 3
# No. of repeatitions completed: 4
# No. of repeatitions completed: 5
# No. of repeatitions completed: 6
# No. of repeatitions completed: 7
# No. of repeatitions completed: 8
# No. of repeatitions completed: 9
# No. of repeatitions completed: 10
# No. of repeatitions completed: 11
# No. of repeatitions completed: 12
# No. of repeatitions completed: 13
# No. of repeatitions completed: 14
# No. of repeatitions completed: 15
# No. of repeatitions completed: 16
# No. of repeatitions completed: 17
# No. of repeatitions completed: 18
# No. of repeatitions completed: 19
# Model::::::::::::::::::::::::::::::: 19
# Completed.....................
